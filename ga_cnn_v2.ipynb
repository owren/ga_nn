# %%
import numpy as np

from fashion_mnist_cnn_v2 import *

# %%
def selection(pop, fitness, num_parents):
    # We select the ones with the highest fitness
    sorted_indecies = np.argsort(fitness)[::-1] # we reverse array, because we want ascending
    top_indecies = sorted_indecies[:num_parents]
    parents = pop[top_indecies]
    return parents

def crossover(parents, offspring_size):
    offspring = np.empty((offspring_size, parents.shape[1]))
    # The point at which crossover takes place between two parents
    crossover_part = int(parents.shape[1]/2)
    # Define all the offsprings
    for k in range(0, offspring_size, 2):
        # we assign random from the two parents
        random_choice = np.random.choice(parents.shape[1], crossover_part, replace=False)
        gene_selection = np.zeros(parents.shape[1])
        gene_selection[random_choice] = 1
        # Index of the first parent to mate.
        parent1_idx = k%parents.shape[0]
        # Index of the second parent to mate.
        parent2_idx = (k+1)%parents.shape[0]
        # Assign the correct parts of the parents to the offspring
        offspring[k, np.where(gene_selection == 0)[0]] = parents[parent1_idx, np.where(gene_selection == 0)[0]]
        offspring[k, np.where(gene_selection == 1)[0]] = parents[parent2_idx, np.where(gene_selection == 1)[0]]
        offspring[k+1, np.where(gene_selection == 1)[0]] = parents[parent1_idx, np.where(gene_selection == 1)[0]]
        offspring[k+1, np.where(gene_selection == 0)[0]] = parents[parent2_idx, np.where(gene_selection == 0)[0]]
    return offspring

def mutation(offspring_crossover, r_mut=0.2, v_mut=0.2):
    # Do if mutation stikes, must be changed if number of options exceed 2
    for idx in range(offspring_crossover.shape[0]):
        for gene_idx in range(offspring_crossover.shape[1]): 
            # Flip gene if mutation happens
            if (np.random.rand() < r_mut): 
                new_value = offspring_crossover[idx, gene_idx] + (np.random.rand()*2-1)*v_mut
                if (new_value < 0): 
                    new_value = 0
                elif (new_value >= 1): 
                    new_value = 0.99
                offspring_crossover[idx, gene_idx] = new_value 
                #offspring_crossover[idx, gene_idx] = 1-offspring_crossover[idx, gene_idx]# bit flip
    return offspring_crossover

# %%
"""
The target is to maximize the accuracy of the cnn-mnist model:
    We start by having a few decisions related to the model. 
    // Model hyper-parameters
    x1 = 32-128 filters in each CNN layer
    x2 = 50-100 neurons in first dense layer
    x3 = no dropout, 0.1 dropout, 0.2 dropout
    x4 = learning rate 0.005 or 0.05 
    x5 = kernel size cnn 2-4
    
    // Data augmentation hyper-parameters
    x6 = rotation_range: 0-30
    x7 = width_shift_range: 0.0-0.3,
    x8 = height_shift_range: 0.0-0.3
    x9 = horizontal_flip: 0 or 1
    
    We will use a genetic algorithm to find the best combinations of these hyperparameters. 
    The fitness-function is based on model accuracy on test-dataset. 
"""
num_weights = 9

# solutions per populations and number of mating parents
sol_per_pop = 6
num_parents = 3

# %%
# Defining the population size.
pop_size = (sol_per_pop,num_weights) # The population will have sol_per_pop chromosome where each chromosome has num_weights genes.
#Creating the initial population.
new_population = np.random.uniform(low=0, high=1, size=pop_size)
print(new_population)
# Out:
# [[0.74037167 0.4099496  0.10700141 0.82154997 0.12580744 0.82534966
#   0.2089763  0.02643974 0.4974076 ]
#  [0.59555797 0.2135547  0.30959775 0.22033295 0.05368361 0.54768959
#   0.29424988 0.47143987 0.85986344]
#  [0.13947814 0.24184284 0.73953399 0.37256134 0.26417414 0.56936304
#   0.21418519 0.11457757 0.6163004 ]
#  [0.88537386 0.98025384 0.29799092 0.55029356 0.05576576 0.44821935
#   0.49676298 0.66463962 0.30668779]
#  [0.08431895 0.55684617 0.09736169 0.41034473 0.54115522 0.3095216
#   0.62258839 0.54324093 0.83692658]
#  [0.05715461 0.46610457 0.29783137 0.64388566 0.73804022 0.26118112
#   0.91260881 0.26015466 0.132359  ]]

# %%
best_outputs = []
num_generations = 10
generation_results = []
checkpoint_file = "fit_pop.json"

# %%
for generation in range(num_generations):
    print("Generation : ", generation)
    # Measuring the fitness of each chromosome in the population.
    fitness = evaluate_model_ga(new_population)
    print("Fitness")
    print(fitness)
    
    # save the results into a list and do intemediate saving
    generation_results.append({"fitness": fitness, "population": new_popolation})
    with open(checkpoint_file, "w") as f: 
        json.dump(generation_results, f)
    
    # Find best result from gen x
    generation_best = (np.max(fitness), new_population[np.where(fitness == np.max(fitness))[0]])
    best_outputs.append(generation_best)
    # The best result in the current iteration.
    print("Best result : ", generation_best)
    
    # Selecting the best parents in the population for mating.
    parents = selection(new_population, fitness, num_parents)
    print("Parents")
    print(parents)

    # Generating next generation using crossover.
    offspring_crossover = crossover(parents, sol_per_pop)
    print("Crossover")
    print(offspring_crossover)

    # Adding some variations to the offspring using mutation.
    offspring_mutation = mutation(offspring_crossover, r_mut=0.2)
    print("Mutation")
    print(offspring_mutation)

    # Creating the new population based on the parents and offspring.
    new_population = offspring_mutation
# Out:
# Generation :  0
# Epoch 1/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.8495 - accuracy: 0.6824 - val_loss: 0.5257 - val_accuracy: 0.8069
# Epoch 2/30
# 1500/1500 [==============================] - 25s 16ms/step - loss: 0.4963 - accuracy: 0.8131 - val_loss: 0.4187 - val_accuracy: 0.8451
# Epoch 3/30
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.4399 - accuracy: 0.8357 - val_loss: 0.3976 - val_accuracy: 0.8507
# Epoch 4/30
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.4162 - accuracy: 0.8459 - val_loss: 0.4158 - val_accuracy: 0.8469
# Epoch 5/30
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.4027 - accuracy: 0.8509 - val_loss: 0.3980 - val_accuracy: 0.8496
# Epoch 6/30
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.3995 - accuracy: 0.8508 - val_loss: 0.3800 - val_accuracy: 0.8651
# Epoch 7/30
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.3832 - accuracy: 0.8584 - val_loss: 0.3768 - val_accuracy: 0.8623
# Epoch 8/30
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.3781 - accuracy: 0.8591 - val_loss: 0.3770 - val_accuracy: 0.8591
# Epoch 9/30
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.3727 - accuracy: 0.8602 - val_loss: 0.3837 - val_accuracy: 0.8604
# Epoch 10/30
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.3602 - accuracy: 0.8658 - val_loss: 0.3850 - val_accuracy: 0.8622
# Accuracy pop: > 85.050 [0.74037167 0.4099496  0.10700141 0.82154997 0.12580744 0.82534966
#  0.2089763  0.02643974 0.4974076 ]
# Epoch 1/30
# 1500/1500 [==============================] - 24s 15ms/step - loss: 0.9503 - accuracy: 0.6381 - val_loss: 0.5973 - val_accuracy: 0.7718
# Epoch 2/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0
30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4963 - accuracy: 0.8129 - val_loss: 0.4462 - val_accuracy: 0.8304
# Epoch 7/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4783 - accuracy: 0.8197 - val_loss: 0.4560 - val_accuracy: 0.8241
# Epoch 8/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4683 - accuracy: 0.8234 - val_loss: 0.4431 - val_accuracy: 0.8343
# Epoch 9/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4603 - accuracy: 0.8278 - val_loss: 0.4641 - val_accuracy: 0.8175
# Epoch 10/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4550 - accuracy: 0.8271 - val_loss: 0.4413 - val_accuracy: 0.8363
# Epoch 11/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4454 - accuracy: 0.8314 - val_loss: 0.4347 - val_accuracy: 0.8331
# Epoch 12/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4391 - accuracy: 0.8355 - val_loss: 0.4230 - val_accuracy: 0.8396
# Epoch 13/30
# 1500/1500 [==============================] - 22s 14ms/step - loss: 0.4482 - accuracy: 0.8302 - val_loss: 0.4183 - val_accuracy: 0.8402
# Epoch 14/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.4381 - accuracy: 0.8337 - val_loss: 0.4196 - val_accuracy: 0.8421
# Epoch 15/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4354 - accuracy: 0.8365 - val_loss: 0.4276 - val_accuracy: 0.8404
# Epoch 16/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4273 - accuracy: 0.8396 - val_loss: 0.4566 - val_accuracy: 0.8268
# Accuracy pop: > 84.020 [0.08431895 0.55684617 0.09736169 0.41034473 0.54115522 0.3095216
#  0.62258839 0.54324093 0.83692658]
# Epoch 1/30
# 1500/1500 [==============================] - 22s 14ms/step - loss: 1.0884 - accuracy: 0.5964 - val_loss: 0.6717 - val_accuracy: 0.7525
# Epoch 2/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.6577 - accuracy: 0.7483 - val_loss: 0.5681 - val_accuracy: 0.7821
# Epoch 3/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.5956 - accuracy: 0.7740 - val_loss: 0.5383 - val_accuracy: 0.7936
# Epoch 4/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.5604 - accuracy: 0.7896 - val_loss: 0.5535 - val_accuracy: 0.7897
# Epoch 5/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.5487 - accuracy: 0.7917 - val_loss: 0.5052 - val_accuracy: 0.8096
# Epoch 6/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.5285 - accuracy: 0.7983 - val_loss: 0.5292 - val_accuracy: 0.7977
# Epoch 7/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.5231 - accuracy: 0.8062 - val_loss: 0.4879 - val_accuracy: 0.8172
# Epoch 8/30
# 1500/1500 [==============================] - 22s 14ms/step - loss: 0.5188 - accuracy: 0.8017 - val_loss: 0.5082 - val_accuracy: 0.8055
# Epoch 9/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.5020 - accuracy: 0.8107 - val_loss: 0.4739 - val_accuracy: 0.8235
# Epoch 10/30
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.4954 - accuracy: 0.8129 - val_loss: 0.4757 - val_accuracy: 0.8195
# Epoch 11/30
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.4901 - accuracy: 0.8139 - val_loss: 0.4629 - val_accuracy: 0.8238
# Epoch 12/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.4817 - accuracy: 0.8183 - val_loss: 0.4721 - val_accuracy: 0.8238
# Epoch 13/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4813 - accuracy: 0.8152 - val_loss: 0.4562 - val_accuracy: 0.8280
# Epoch 14/30
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.4845 - accuracy: 0.8183 - val_loss: 0.4633 - val_accuracy: 0.8241
# Epoch 15/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4857 - accuracy: 0.8199 - val_loss: 0.4542 - val_accuracy: 0.8306
# Epoch 16/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4660 - accuracy: 0.8239 - val_loss: 0.4373 - val_accuracy: 0.8371
# Epoch 17/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4658 - accuracy: 0.8230 - val_loss: 0.4824 - val_accuracy: 0.8137
# Epoch 18/30
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.3942 - accuracy: 0.8533 - val_loss: 0.4190 - val_accuracy: 0.8422
# Epoch 8/30
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.3788 - accuracy: 0.8560 - val_loss: 0.3382 - val_accuracy: 0.8716
# Epoch 9/30
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.3714 - accuracy: 0.8620 - val_loss: 0.3271 - val_accuracy: 0.8800
# Epoch 10/30
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.3690 - accuracy: 0.8613 - val_loss: 0.3360 - val_accuracy: 0.8762
# Epoch 11/30
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.3643 - accuracy: 0.8636 - val_loss: 0.3199 - val_accuracy: 0.8807
# Epoch 12/30
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.3618 - accuracy: 0.8647 - val_loss: 0.3473 - val_accuracy: 0.8708
# Epoch 13/30
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.3505 - accuracy: 0.8712 - val_loss: 0.3070 - val_accuracy: 0.8842
# Epoch 14/30
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.3377 - accuracy: 0.8734 - val_loss: 0.3241 - val_accuracy: 0.8803
# Epoch 15/30
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.3458 - accuracy: 0.8712 - val_loss: 0.3366 - val_accuracy: 0.8702
# Epoch 16/30
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.3427 - accuracy: 0.8715 - val_loss: 0.3180 - val_accuracy: 0.8823
# Accuracy pop: > 88.100 [0.22217312 0.05050077 0.60197169 0.37256134 0.26417414 0.54768959
#  0.12507713 0.11457757 0.85986344]
# Epoch 1/30
# 1500/1500 [==============================] - 24s 15ms/step - loss: 0.9612 - accuracy: 0.6355 - val_loss: 0.6017 - val_accuracy: 0.7627
# Epoch 2/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.6079 - accuracy: 0.7675 - val_loss: 0.5651 - val_accuracy: 0.7745
# Epoch 3/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.5227 - accuracy: 0.8011 - val_loss: 0.4720 - val_accuracy: 0.8230
# Epoch 4/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.4857 - accuracy: 0.8160 - val_loss: 0.4527 - val_accuracy: 0.8274
# Epoch 5/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.4681 - accuracy: 0.8220 - val_loss: 0.4378 - val_accuracy: 0.8365
# Epoch 6/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.4453 - accuracy: 0.8309 - val_loss: 0.4097 - val_accuracy: 0.8440
# Epoch 7/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.4253 - accuracy: 0.8429 - val_loss: 0.3985 - val_accuracy: 0.8529
# Epoch 8/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.4134 - accuracy: 0.8439 - val_loss: 0.3915 - val_accuracy: 0.8547
# Epoch 9/30
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.4093 - accuracy: 0.8458 - val_loss: 0.3655 - val_accuracy: 0.8662
# Epoch 10/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.3973 - accuracy: 0.8501 - val_loss: 0.4015 - val_accuracy: 0.8493
# Epoch 11/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.3976 - accuracy: 0.8503 - val_loss: 0.3615 - val_accuracy: 0.8633
# Epoch 12/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.3880 - accuracy: 0.8504 - val_loss: 0.3849 - val_accuracy: 0.8574
# Epoch 13/30
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.3801 - accuracy: 0.8583 - val_loss: 0.3641 - val_accuracy: 0.8630
# Epoch 14/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.3705 - accuracy: 0.8595 - val_loss: 0.3513 - val_accuracy: 0.8687
# Epoch 15/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.3705 - accuracy: 0.8616 - val_loss: 0.3434 - val_accuracy: 0.8693
# Epoch 16/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.3689 - accuracy: 0.8601 - val_loss: 0.3442 - val_accuracy: 0.8723
# Epoch 17/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.3648 - accuracy: 0.8618 - val_loss: 0.3849 - val_accuracy: 0.8564
# Epoch 18/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.3628 - accuracy: 0.8605 - val_loss: 0.3518 - val_accuracy: 0.8687
# Accuracy pop: > 87.290 [0.59555797 0.24184284 0.30959775 0.22033295 0.05368361 0.56936304
#  0.21418519 0.47143987 0.6163004 ]
# Epoch 1/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 1.1639 - accuracy: 0.5580 - val_loss: 0.6894 - val_accuracy: 0.7402
# Epoch 2/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.6840 - accuracy: 0.7357 - val_loss: 0.6169 - val_accuracy: 0.7691
# Epoch 3/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.6185 - accuracy: 0.7672 - val_loss: 0.5935 - val_accuracy: 0.7732
# Epoch 4/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.5792 - accuracy: 0.7789 - val_loss: 0.5332 - val_accuracy: 0.8012
# Epoch 5/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.5541 - accuracy: 0.7923 - val_loss: 0.4950 - val_accuracy: 0.8118
# Epoch 6/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.5282 - accuracy: 0.8011 - val_loss: 0.4872 - val_accuracy: 0.8162
# Epoch 7/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.5107 - accuracy: 0.8093 - val_loss: 0.4651 - val_accuracy: 0.8260
# Epoch 8/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.4943 - accuracy: 0.8109 - val_loss: 0.4652 - val_accuracy: 0.8271
# Epoch 9/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.4961 - accuracy: 0.8159 - val_loss: 0.4650 - val_accuracy: 0.8253
# Epoch 10/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.4891 - accuracy: 0.8166 - val_loss: 0.4878 - val_accuracy: 0.8149
# Epoch 11/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.4844 - accuracy: 0.8202 - val_loss: 0.4455 - val_accuracy: 0.8317
# Epoch 12/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.4759 - accuracy: 0.8219 - val_loss: 0.4452 - val_accuracy: 0.8323
# Epoch 13/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.4683 - accuracy: 0.8248 - val_loss: 0.4308 - val_accuracy: 0.8396
# Epoch 14/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.4616 - accuracy: 0.8293 - val_loss: 0.4430 - val_accuracy: 0.8368
# Epoch 15/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.4646 - accuracy: 0.8262 - val_loss: 0.4261 - val_accuracy: 0.8454
# Epoch 16/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.4590 - accuracy: 0.8282 - val_loss: 0.4477 - val_accuracy: 0.8322
# Epoch 17/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.4522 - accuracy: 0.8312 - val_loss: 0.4065 - val_accuracy: 0.8472
# Epoch 18/30
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.4468 - accuracy: 0.8331 - val_loss: 0.4137 - val_accuracy: 0.8445
# Epoch 19/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.4348 - accuracy: 0.8391 - val_loss: 0.4122 - val_accuracy: 0.8455
# Epoch 20/30
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.4348 - accuracy: 0.8372 - val_loss: 0.4175 - val_accuracy: 0.8423
# Accuracy pop: > 84.420 [0.88537386 0.24184284 0.42060104 0.37256134 0.26417414 0.44821935
#  0.49676298 0.7973699  0.6163004 ]
# Epoch 1/30
# 1500/1500 [==============================] - 22s 14ms/step - loss: 0.9065 - accuracy: 0.6587 - val_loss: 0.5233 - val_accuracy: 0.8012
# Epoch 2/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.5502 - accuracy: 0.7919 - val_loss: 0.4693 - val_accuracy: 0.8238
# Epoch 3/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.5062 - accuracy: 0.8097 - val_loss: 0.4334 - val_accuracy: 0.8322
# Epoch 4/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4724 - accuracy: 0.8183 - val_loss: 0.4023 - val_accuracy: 0.8442
# Epoch 5/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4575 - accuracy: 0.8276 - val_loss: 0.4084 - val_accuracy: 0.8464
# Epoch 6/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4487 - accuracy: 0.8317 - val_loss: 0.3959 - val_accuracy: 0.8504
# Epoch 7/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4364 - accuracy: 0.8337 - val_loss: 0.3917 - val_accuracy: 0.8531
# Epoch 8/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4202 - accuracy: 0.8412 - val_loss: 0.4723 - val_accuracy: 0.8171
# Epoch 9/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4199 - accuracy: 0.8409 - val_loss: 0.3596 - val_accuracy: 0.8625
# Epoch 10/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4242 - accuracy: 0.8418 - val_loss: 0.3769 - val_accuracy: 0.8599
# Epoch 11/30
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.4100 - accuracy: 0.8470 - val_loss: 0.3611 - val_accuracy: 0.8618
# Epoch 12/30
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4040 - accuracy: 0.8482 - val_loss: 0.3839 - val_accuracy: 0.8544
# Accuracy pop: > 86.640 [0.         0.96094713 0.54577862 0.55029356 0.05576576 0.56936304
#  0.39370769 0.11457757 0.30668779]
# Epoch 1/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 1.0061 - accuracy: 0.6155 - val_loss: 0.6022 - val_accuracy: 0.7753
# Epoch 2/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.6097 - accuracy: 0.7659 - val_loss: 0.5161 - val_accuracy: 0.7995
# Epoch 3/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.5613 - accuracy: 0.7859 - val_loss: 0.4947 - val_accuracy: 0.8111
# Epoch 4/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.5299 - accuracy: 0.7974 - val_loss: 0.4688 - val_accuracy: 0.8238
# Epoch 5/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.4984 - accuracy: 0.8114 - val_loss: 0.4404 - val_accuracy: 0.8351
# Epoch 6/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.4859 - accuracy: 0.8158 - val_loss: 0.4853 - val_accuracy: 0.8158
# Epoch 7/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.4719 - accuracy: 0.8192 - val_loss: 0.4292 - val_accuracy: 0.8407
# Epoch 8/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.4608 - accuracy: 0.8260 - val_loss: 0.4535 - val_accuracy: 0.8308
# Epoch 9/30
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.4602 - accuracy: 0.8235 - val_loss: 0.4401 - val_accuracy: 0.8334
# Epoch 10/30
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.4450 - accuracy: 0.8301 - val_loss: 0.4366 - val_accuracy: 0.8363
# Accuracy pop: > 84.250 [0.59555797 0.2135547  0.30959775 0.55029356 0.05368361 0.44821935
#  0.49676298 0.47143987 0.30668779]
# Epoch 1/30
# 1500/1500 [==============================] - 30s 20ms/step - loss: 0.9681 - accuracy: 0.6329 - val_loss: 0.6082 - val_accuracy: 0.7683
# Epoch 2/30
# 1500/1500 [==============================] - 28s 19ms/step - loss: 0.6072 - accuracy: 0.7649 - val_loss: 0.5355 - val_accuracy: 0.7945
# Epoch 3/30
# 1328/1500 [=========================>....] - ETA: 2s - loss: 0.5426 - accuracy: 0.7953
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-a94563d5683a> in <module>
#       2     print("Generation : ", generation)
#       3     # Measuring the fitness of each chromosome in the population.
# ----> 4     fitness = evaluate_model_ga(new_population)
#       5     print("Fitness")
#       6     print(fitness)
#
# ~\git_repos\ga_nn\fashion_mnist_cnn_v2.py in evaluate_model_ga(pop)
#     111             callback = tf.keras.callbacks.EarlyStopping(patience=5)
#     112             # fit model
# --> 113             model.fit(datagen.flow(trainX, trainY, batch_size=32,subset='training'),
#     114                       validation_data=datagen.flow(trainX, trainY,batch_size=8, subset='validation'),
#     115                       epochs=30,callbacks=[callback], verbose=1)
#
# ~\miniconda3\envs\tf_env\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~\miniconda3\envs\tf_env\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\miniconda3\envs\tf_env\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~\miniconda3\envs\tf_env\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# ~\miniconda3\envs\tf_env\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916         and executing_eagerly):
#    1917       # No tape is watching; skip to running the function.
# -> 1918       return self._build_call_outputs(self._inference_function.call(
#    1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#
# ~\miniconda3\envs\tf_env\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     553       with _InterpolateFunctionError(self):
#     554         if cancellation_manager is None:
# --> 555           outputs = execute.execute(
#     556               str(self.signature.name),
#     557               num_outputs=self._num_outputs,
#
# ~\miniconda3\envs\tf_env\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
